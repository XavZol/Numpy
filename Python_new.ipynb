# %%
import numpy as np
import pandas as pd 
import time 

array = np.array([1 , 2 , 3 ])
print(len(array))
# Out:
# 3

# %%
print(array.shape)
# Out:
# (3,)

# %%
array_2d = np.array([[1, 2, 3], [4, 5, 6]])

print(array_2d)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(len(array_2d))
# Out:
# 2

# %%
print(array_2d.shape)
# Out:
# (2, 3)
